# %% [markdown]
# # HOUSE

# %% [markdown]
# Houses are one of the necessary need of each and every person around the globe and therefore housing and real estate
# market is one of the markets which is one of the major contributors in the world’s economy. It is a very large market
# and there are various companies working in the domain. Data science comes as a very important tool to solve problems
# in the domain to help the companies increase their overall revenue, profits, improving their marketing strategies and
# focusing on changing trends in house sales and purchases. Predictive modelling, Market mix modelling,
# recommendation systems are some of the machine learning techniques used for achieving the business goals for housing
# companies. Our problem is related to one such housing company.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('train.housing.csv')
pd.options.display.max_columns=None
pd.options.display.max_rows=None
df.head()
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  127         120       RL          NaN     4928   Pave   NaN      IR1
# 1  889          20       RL         95.0    15865   Pave   NaN      IR1
# 2  793          60       RL         92.0     9920   Pave   NaN      IR1
# 3  110          20       RL        105.0    11751   Pave   NaN      IR1
# 4  422          20       RL          NaN    16635   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      NPkVill       Norm
# 1         Lvl    AllPub    Inside       Mod        NAmes       Norm
# 2         Lvl    AllPub   CulDSac       Gtl      NoRidge       Norm
# 3         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 4         Lvl    AllPub       FR2       Gtl       NWAmes       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm   TwnhsE     1Story            6            5       1976
# 1       Norm     1Fam     1Story            8            6       1970
# 2       Norm     1Fam     2Story            7            5       1996
# 3       Norm     1Fam     1Story            6            6       1977
# 4       Norm     1Fam     1Story            6            7       1977
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          1976     Gable  CompShg     Plywood     Plywood       None
# 1          1970      Flat  Tar&Grv     Wd Sdng     Wd Sdng       None
# 2          1997     Gable  CompShg     MetalSd     MetalSd       None
# 3          1977       Hip  CompShg     Plywood     Plywood    BrkFace
# 4          2000     Gable  CompShg     CemntBd     CmentBd      Stone
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0         0.0        TA        TA     CBlock       Gd       TA           No
# 1         0.0        Gd        Gd      PConc       TA       Gd           Gd
# 2         0.0        Gd        TA      PConc       Gd       TA           Av
# 3       480.0        TA        TA     CBlock       Gd       TA           No
# 4       126.0        Gd        TA     CBlock       Gd       TA           No
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          ALQ         120          Unf           0        958         1078
# 1          ALQ         351          Rec         823       1043         2217
# 2          GLQ         862          Unf           0        255         1117
# 3          BLQ         705          Unf           0       1139         1844
# 4          ALQ        1246          Unf           0        356         1602
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        TA          Y      SBrkr       958         0             0
# 1    GasA        Ex          Y      SBrkr      2217         0             0
# 2    GasA        Ex          Y      SBrkr      1127       886             0
# 3    GasA        Ex          Y      SBrkr      1844         0             0
# 4    GasA        Gd          Y      SBrkr      1602         0             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0        958             0             0         2         0             2
# 1       2217             1             0         2         0             4
# 2       2013             1             0         2         1             3
# 3       1844             0             0         2         0             3
# 4       1602             0             1         2         0             3
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          TA             5        Typ           1          TA
# 1             1          Gd             8        Typ           1          TA
# 2             1          TA             8        Typ           1          TA
# 3             1          TA             7        Typ           1          TA
# 4             1          Gd             8        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       1977.0          RFn           2         440         TA
# 1     Attchd       1970.0          Unf           2         621         TA
# 2     Attchd       1997.0          Unf           2         455         TA
# 3     Attchd       1977.0          RFn           2         546         TA
# 4     Attchd       1977.0          Fin           2         529         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0          205              0          0
# 1         TA          Y          81          207              0          0
# 2         TA          Y         180          130              0          0
# 3         TA          Y           0          122              0          0
# 4         TA          Y         240            0              0          0
#
#    ScreenPorch  PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN    NaN         NaN        0       2    2007
# 1          224         0    NaN    NaN         NaN        0      10    2007
# 2            0         0    NaN    NaN         NaN        0       6    2007
# 3            0         0    NaN  MnPrv         NaN        0       1    2010
# 4            0         0    NaN    NaN         NaN        0       6    2009
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     128000
# 1       WD        Normal     268000
# 2       WD        Normal     269790
# 3      COD        Normal     190000
# 4       WD        Normal     215000

# %%
df.shape
# Out:
# (1168, 81)

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
for i in df.columns:
    if df[i].isnull().sum()>0:
        print(i,df[i].isnull().sum())
# Out:
# LotFrontage 214
# Alley 1091
# MasVnrType 7
# MasVnrArea 7
# BsmtQual 30
# BsmtCond 30
# BsmtExposure 31
# BsmtFinType1 30
# BsmtFinType2 31
# FireplaceQu 551
# GarageType 64
# GarageYrBlt 64
# GarageFinish 64
# GarageQual 64
# GarageCond 64
# PoolQC 1161
# Fence 931
# MiscFeature 1124

# %%
df.drop(['Id','PoolQC','Fence','MiscFeature','Alley'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0         120       RL          NaN     4928   Pave      IR1         Lvl
# 1          20       RL         95.0    15865   Pave      IR1         Lvl
# 2          60       RL         92.0     9920   Pave      IR1         Lvl
# 3          20       RL        105.0    11751   Pave      IR1         Lvl
# 4          20       RL          NaN    16635   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      NPkVill       Norm       Norm   TwnhsE
# 1    AllPub    Inside       Mod        NAmes       Norm       Norm     1Fam
# 2    AllPub   CulDSac       Gtl      NoRidge       Norm       Norm     1Fam
# 3    AllPub    Inside       Gtl       NWAmes       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl       NWAmes       Norm       Norm     1Fam
#
#   HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# 0     1Story            6            5       1976          1976     Gable
# 1     1Story            8            6       1970          1970      Flat
# 2     2Story            7            5       1996          1997     Gable
# 3     1Story            6            6       1977          1977       Hip
# 4     1Story            6            7       1977          2000     Gable
#
#   RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond  \
# 0  CompShg     Plywood     Plywood       None         0.0        TA        TA
# 1  Tar&Grv     Wd Sdng     Wd Sdng       None         0.0        Gd        Gd
# 2  CompShg     MetalSd     MetalSd       None         0.0        Gd        TA
# 3  CompShg     Plywood     Plywood    BrkFace       480.0        TA        TA
# 4  CompShg     CemntBd     CmentBd      Stone       126.0        Gd        TA
#
#   Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1  \
# 0     CBlock       Gd       TA           No          ALQ         120
# 1      PConc       TA       Gd           Gd          ALQ         351
# 2      PConc       Gd       TA           Av          GLQ         862
# 3     CBlock       Gd       TA           No          BLQ         705
# 4     CBlock       Gd       TA           No          ALQ        1246
#
#   BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC  \
# 0          Unf           0        958         1078    GasA        TA
# 1          Rec         823       1043         2217    GasA        Ex
# 2          Unf           0        255         1117    GasA        Ex
# 3          Unf           0       1139         1844    GasA        Ex
# 4          Unf           0        356         1602    GasA        Gd
#
#   CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  \
# 0          Y      SBrkr       958         0             0        958
# 1          Y      SBrkr      2217         0             0       2217
# 2          Y      SBrkr      1127       886             0       2013
# 3          Y      SBrkr      1844         0             0       1844
# 4          Y      SBrkr      1602         0             0       1602
#
#    BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 0             0             0         2         0             2             1
# 1             1             0         2         0             4             1
# 2             1             0         2         1             3             1
# 3             0             0         2         0             3             1
# 4             0             1         2         0             3             1
#
#   KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  \
# 0          TA             5        Typ           1          TA     Attchd
# 1          Gd             8        Typ           1          TA     Attchd
# 2          TA             8        Typ           1          TA     Attchd
# 3          TA             7        Typ           1          TA     Attchd
# 4          Gd             8        Typ           1          TA     Attchd
#
#    GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond  \
# 0       1977.0          RFn           2         440         TA         TA
# 1       1970.0          Unf           2         621         TA         TA
# 2       1997.0          Unf           2         455         TA         TA
# 3       1977.0          RFn           2         546         TA         TA
# 4       1977.0          Fin           2         529         TA         TA
#
#   PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0          Y           0          205              0          0            0
# 1          Y          81          207              0          0          224
# 2          Y         180          130              0          0            0
# 3          Y           0          122              0          0            0
# 4          Y         240            0              0          0            0
#
#    PoolArea  MiscVal  MoSold  YrSold SaleType SaleCondition  SalePrice
# 0         0        0       2    2007       WD        Normal     128000
# 1         0        0      10    2007       WD        Normal     268000
# 2         0        0       6    2007       WD        Normal     269790
# 3         0        0       1    2010      COD        Normal     190000
# 4         0        0       6    2009       WD        Normal     215000

# %% [markdown]
# ### Analyzing the Data

# %%
df.drop(['BsmtFinSF1','BsmtFinSF2','BsmtUnfSF'],axis=1,inplace=True)

# %% [markdown]
# ###### We dropped the BsmtFinSF1,BsmtFinSF2,BsmtUnSF columns because total of these threee columns is TotalBsmtSF column.

# %%
df['BsmtHalfBath'] = 0.5 * df['BsmtHalfBath']
df['HalfBath'] = 0.5 * df['HalfBath']

# %%
df['BsmtBath'] = df['BsmtHalfBath'] + df['BsmtFullBath']
df['Bath'] = df['HalfBath'] + df['FullBath']

# %%
df.drop(['BsmtFullBath','BsmtHalfBath','FullBath','HalfBath'],axis=1,inplace=True)

# %% [markdown]
# ###### We multiply the BsmtHalfBath and HalfBath column with 0.5 and then concate the FullBath with HalfBath and BsmtHalfBath with BsmtFullBath. After concatenating the columns we dropped  BsmtFullBath,BsmtHalfBath,FullBath,HalfBath columns.

# %%
df['Total_porch'] = df['OpenPorchSF'] + df['EnclosedPorch'] + df['3SsnPorch'] + df['ScreenPorch']

# %%
df.drop(['OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch'],axis=1,inplace=True)

# %% [markdown]
# ###### After concatenating the four columns,OpenPorchSF,EnclosedPorch,3SsnPorch,	ScreenPorch we dropped these columns and added a new column to a dataset.

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0         120       RL          NaN     4928   Pave      IR1         Lvl
# 1          20       RL         95.0    15865   Pave      IR1         Lvl
# 2          60       RL         92.0     9920   Pave      IR1         Lvl
# 3          20       RL        105.0    11751   Pave      IR1         Lvl
# 4          20       RL          NaN    16635   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      NPkVill       Norm       Norm   TwnhsE
# 1    AllPub    Inside       Mod        NAmes       Norm       Norm     1Fam
# 2    AllPub   CulDSac       Gtl      NoRidge       Norm       Norm     1Fam
# 3    AllPub    Inside       Gtl       NWAmes       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl       NWAmes       Norm       Norm     1Fam
#
#   HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# 0     1Story            6            5       1976          1976     Gable
# 1     1Story            8            6       1970          1970      Flat
# 2     2Story            7            5       1996          1997     Gable
# 3     1Story            6            6       1977          1977       Hip
# 4     1Story            6            7       1977          2000     Gable
#
#   RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond  \
# 0  CompShg     Plywood     Plywood       None         0.0        TA        TA
# 1  Tar&Grv     Wd Sdng     Wd Sdng       None         0.0        Gd        Gd
# 2  CompShg     MetalSd     MetalSd       None         0.0        Gd        TA
# 3  CompShg     Plywood     Plywood    BrkFace       480.0        TA        TA
# 4  CompShg     CemntBd     CmentBd      Stone       126.0        Gd        TA
#
#   Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2  \
# 0     CBlock       Gd       TA           No          ALQ          Unf
# 1      PConc       TA       Gd           Gd          ALQ          Rec
# 2      PConc       Gd       TA           Av          GLQ          Unf
# 3     CBlock       Gd       TA           No          BLQ          Unf
# 4     CBlock       Gd       TA           No          ALQ          Unf
#
#    TotalBsmtSF Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  \
# 0         1078    GasA        TA          Y      SBrkr       958         0
# 1         2217    GasA        Ex          Y      SBrkr      2217         0
# 2         1117    GasA        Ex          Y      SBrkr      1127       886
# 3         1844    GasA        Ex          Y      SBrkr      1844         0
# 4         1602    GasA        Gd          Y      SBrkr      1602         0
#
#    LowQualFinSF  GrLivArea  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 0             0        958             2             1          TA
# 1             0       2217             4             1          Gd
# 2             0       2013             3             1          TA
# 3             0       1844             3             1          TA
# 4             0       1602             3             1          Gd
#
#    TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 0             5        Typ           1          TA     Attchd       1977.0
# 1             8        Typ           1          TA     Attchd       1970.0
# 2             8        Typ           1          TA     Attchd       1997.0
# 3             7        Typ           1          TA     Attchd       1977.0
# 4             8        Typ           1          TA     Attchd       1977.0
#
#   GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 0          RFn           2         440         TA         TA          Y
# 1          Unf           2         621         TA         TA          Y
# 2          Unf           2         455         TA         TA          Y
# 3          RFn           2         546         TA         TA          Y
# 4          Fin           2         529         TA         TA          Y
#
#    WoodDeckSF  PoolArea  MiscVal  MoSold  YrSold SaleType SaleCondition  \
# 0           0         0        0       2    2007       WD        Normal
# 1          81         0        0      10    2007       WD        Normal
# 2         180         0        0       6    2007       WD        Normal
# 3           0         0        0       1    2010      COD        Normal
# 4         240         0        0       6    2009       WD        Normal
#
#    SalePrice  BsmtBath  Bath  Total_porch
# 0     128000       0.0   2.0          205
# 1     268000       1.0   2.0          431
# 2     269790       1.0   2.5          130
# 3     190000       0.0   2.0          122
# 4     215000       0.5   2.0            0

# %%
df.shape
# Out:
# (1168, 68)

# %% [markdown]
# ###### Now we have 1168 rows and 68 columns.

# %% [markdown]
# ### Handling Missing Values

# %%
df['LotFrontage'] = df['LotFrontage'].fillna(df['LotFrontage'].mean())

# %%
df['MasVnrType'] = df['MasVnrType'].fillna('NA')
df['MasVnrArea'] = df['MasVnrArea'].fillna(df['MasVnrArea'].mean())

# %%
df['BsmtQual'] = df['BsmtQual'].fillna('NA')
df['BsmtCond'] = df['BsmtCond'].fillna('NA')
df['BsmtExposure'] = df['BsmtExposure'].fillna('NA')
df['BsmtFinType1'] = df['BsmtFinType1'].fillna('NA')
df['BsmtFinType2'] = df['BsmtFinType2'].fillna('NA')

# %%
df['FireplaceQu'] = df['FireplaceQu'].fillna('NA')
df['GarageType'] = df['GarageType'].fillna('NA')
df['GarageFinish'] = df['GarageFinish'].fillna('NA')
df['GarageQual'] = df['GarageQual'].fillna('NA')
df['GarageCond'] = df['GarageCond'].fillna('NA')

# %%
df['GarageYrBlt'] = df['GarageYrBlt'].fillna(df['GarageYrBlt'].mean())

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0         120       RL     70.98847     4928   Pave      IR1         Lvl
# 1          20       RL     95.00000    15865   Pave      IR1         Lvl
# 2          60       RL     92.00000     9920   Pave      IR1         Lvl
# 3          20       RL    105.00000    11751   Pave      IR1         Lvl
# 4          20       RL     70.98847    16635   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      NPkVill       Norm       Norm   TwnhsE
# 1    AllPub    Inside       Mod        NAmes       Norm       Norm     1Fam
# 2    AllPub   CulDSac       Gtl      NoRidge       Norm       Norm     1Fam
# 3    AllPub    Inside       Gtl       NWAmes       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl       NWAmes       Norm       Norm     1Fam
#
#   HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# 0     1Story            6            5       1976          1976     Gable
# 1     1Story            8            6       1970          1970      Flat
# 2     2Story            7            5       1996          1997     Gable
# 3     1Story            6            6       1977          1977       Hip
# 4     1Story            6            7       1977          2000     Gable
#
#   RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond  \
# 0  CompShg     Plywood     Plywood       None         0.0        TA        TA
# 1  Tar&Grv     Wd Sdng     Wd Sdng       None         0.0        Gd        Gd
# 2  CompShg     MetalSd     MetalSd       None         0.0        Gd        TA
# 3  CompShg     Plywood     Plywood    BrkFace       480.0        TA        TA
# 4  CompShg     CemntBd     CmentBd      Stone       126.0        Gd        TA
#
#   Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2  \
# 0     CBlock       Gd       TA           No          ALQ          Unf
# 1      PConc       TA       Gd           Gd          ALQ          Rec
# 2      PConc       Gd       TA           Av          GLQ          Unf
# 3     CBlock       Gd       TA           No          BLQ          Unf
# 4     CBlock       Gd       TA           No          ALQ          Unf
#
#    TotalBsmtSF Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  \
# 0         1078    GasA        TA          Y      SBrkr       958         0
# 1         2217    GasA        Ex          Y      SBrkr      2217         0
# 2         1117    GasA        Ex          Y      SBrkr      1127       886
# 3         1844    GasA        Ex          Y      SBrkr      1844         0
# 4         1602    GasA        Gd          Y      SBrkr      1602         0
#
#    LowQualFinSF  GrLivArea  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 0             0        958             2             1          TA
# 1             0       2217             4             1          Gd
# 2             0       2013             3             1          TA
# 3             0       1844             3             1          TA
# 4             0       1602             3             1          Gd
#
#    TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 0             5        Typ           1          TA     Attchd       1977.0
# 1             8        Typ           1          TA     Attchd       1970.0
# 2             8        Typ           1          TA     Attchd       1997.0
# 3             7        Typ           1          TA     Attchd       1977.0
# 4             8        Typ           1          TA     Attchd       1977.0
#
#   GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 0          RFn           2         440         TA         TA          Y
# 1          Unf           2         621         TA         TA          Y
# 2          Unf           2         455         TA         TA          Y
# 3          RFn           2         546         TA         TA          Y
# 4          Fin           2         529         TA         TA          Y
#
#    WoodDeckSF  PoolArea  MiscVal  MoSold  YrSold SaleType SaleCondition  \
# 0           0         0        0       2    2007       WD        Normal
# 1          81         0        0      10    2007       WD        Normal
# 2         180         0        0       6    2007       WD        Normal
# 3           0         0        0       1    2010      COD        Normal
# 4         240         0        0       6    2009       WD        Normal
#
#    SalePrice  BsmtBath  Bath  Total_porch
# 0     128000       0.0   2.0          205
# 1     268000       1.0   2.0          431
# 2     269790       1.0   2.5          130
# 3     190000       0.0   2.0          122
# 4     215000       0.5   2.0            0

# %% [markdown]
# ###### We fill all the NaN values

# %% [markdown]
# ### Data  Visualization

# %%
plt.figure(figsize=(20,10))
sns.histplot(x = 'SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Count'>

# %%
plt.figure(figsize=(50,35))
sns.barplot(x = 'YearBuilt',y = 'SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='YearBuilt', ylabel='SalePrice'>

# %%
plt.figure(figsize=(25,15))
sns.barplot(x = 'YearRemodAdd',y = 'SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='YearRemodAdd', ylabel='SalePrice'>

# %%
plt.figure(figsize=(9,7))
sns.barplot(x = 'OverallQual',y = 'SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='OverallQual', ylabel='SalePrice'>

# %%
plt.figure(figsize=(9,7))
sns.barplot(x = 'OverallCond',y = 'SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='OverallCond', ylabel='SalePrice'>

# %%
plt.figure(figsize=(9,7))
sns.barplot(x = 'KitchenQual',y = 'SalePrice',data=df,color='g')
# Out:
# <AxesSubplot:xlabel='KitchenQual', ylabel='SalePrice'>

# %%
plt.figure(figsize=(9,7))
sns.barplot(x = 'TotRmsAbvGrd', y = 'SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='TotRmsAbvGrd', ylabel='SalePrice'>

# %%
plt.figure(figsize=(9,7))
sns.barplot(x = 'GarageType',y = 'SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='GarageType', ylabel='SalePrice'>

# %%
plt.figure(figsize=(9,7))
sns.barplot(x = 'MoSold',y = 'SalePrice',data=df,color='r')
# Out:
# <AxesSubplot:xlabel='MoSold', ylabel='SalePrice'>

# %%
plt.figure(figsize=(9,7))
sns.barplot(x = 'YrSold',y = 'SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='YrSold', ylabel='SalePrice'>

# %% [markdown]
# ### Description

# %%
df.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1168.000000  1168.000000    1168.000000  1168.000000  1168.000000
# mean     56.767979    70.988470   10484.749144     6.104452     5.595890
# std      41.940650    22.437056    8957.442311     1.390153     1.124343
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    60.000000    7621.500000     5.000000     5.000000
# 50%      50.000000    70.988470    9522.500000     6.000000     5.000000
# 75%      70.000000    79.250000   11515.500000     7.000000     6.000000
# max     190.000000   313.000000  164660.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea  TotalBsmtSF     1stFlrSF  \
# count  1168.000000   1168.000000  1168.000000  1168.000000  1168.000000
# mean   1970.930651   1984.758562   102.310078  1061.095034  1169.860445
# std      30.145255     20.785185   182.047152   442.272249   391.161983
# min    1875.000000   1950.000000     0.000000     0.000000   334.000000
# 25%    1954.000000   1966.000000     0.000000   799.000000   892.000000
# 50%    1972.000000   1993.000000     0.000000  1005.500000  1096.500000
# 75%    2000.000000   2004.000000   160.000000  1291.500000  1392.000000
# max    2010.000000   2010.000000  1600.000000  6110.000000  4692.000000
#
#           2ndFlrSF  LowQualFinSF    GrLivArea  BedroomAbvGr  KitchenAbvGr  \
# count  1168.000000   1168.000000  1168.000000   1168.000000   1168.000000
# mean    348.826199      6.380137  1525.066781      2.884418      1.045377
# std     439.696370     50.892844   528.042957      0.817229      0.216292
# min       0.000000      0.000000   334.000000      0.000000      0.000000
# 25%       0.000000      0.000000  1143.250000      2.000000      1.000000
# 50%       0.000000      0.000000  1468.500000      3.000000      1.000000
# 75%     729.000000      0.000000  1795.000000      3.000000      1.000000
# max    2065.000000    572.000000  5642.000000      8.000000      3.000000
#
#        TotRmsAbvGrd   Fireplaces  GarageYrBlt   GarageCars   GarageArea  \
# count   1168.000000  1168.000000  1168.000000  1168.000000  1168.000000
# mean       6.542808     0.617295  1978.193841     1.776541   476.860445
# std        1.598484     0.650575    24.198559     0.745554   214.466769
# min        2.000000     0.000000  1900.000000     0.000000     0.000000
# 25%        5.000000     0.000000  1962.000000     1.000000   338.000000
# 50%        6.000000     1.000000  1978.193841     2.000000   480.000000
# 75%        7.000000     1.000000  2001.000000     2.000000   576.000000
# max       14.000000     3.000000  2010.000000     4.000000  1418.000000
#
#         WoodDeckSF     PoolArea       MiscVal       MoSold       YrSold  \
# count  1168.000000  1168.000000   1168.000000  1168.000000  1168.000000
# mean     96.206336     3.448630     47.315068     6.344178  2007.804795
# std     126.158988    44.896939    543.264432     2.686352     1.329738
# min       0.000000     0.000000      0.000000     1.000000  2006.000000
# 25%       0.000000     0.000000      0.000000     5.000000  2007.000000
# 50%       0.000000     0.000000      0.000000     6.000000  2008.000000
# 75%     171.000000     0.000000      0.000000     8.000000  2009.000000
# max     857.000000   738.000000  15500.000000    12.000000  2010.000000
#
#            SalePrice     BsmtBath         Bath  Total_porch
# count    1168.000000  1168.000000  1168.000000  1168.000000
# mean   181477.005993     0.453339     1.756849    88.266267
# std     79105.586863     0.517233     0.632892   105.912958
# min     34900.000000     0.000000     0.000000     0.000000
# 25%    130375.000000     0.000000     1.000000     0.000000
# 50%    163995.000000     0.000000     2.000000    50.000000
# 75%    215000.000000     1.000000     2.500000   140.000000
# max    755000.000000     3.000000     3.500000  1027.000000

# %% [markdown]
# ### Correlation

# %%
df.corr()
# Out:
#               MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# MSSubClass      1.000000    -0.336681 -0.124151     0.070462    -0.056978
# LotFrontage    -0.336681     1.000000  0.299452     0.229218    -0.047573
# LotArea        -0.124151     0.299452  1.000000     0.107188     0.017513
# OverallQual     0.070462     0.229218  0.107188     1.000000    -0.083167
# OverallCond    -0.056978    -0.047573  0.017513    -0.083167     1.000000
# YearBuilt       0.023988     0.112655  0.005506     0.575800    -0.377731
# YearRemodAdd    0.056618     0.088799  0.027228     0.555945     0.080669
# MasVnrArea      0.027813     0.188758  0.121086     0.407230    -0.137475
# TotalBsmtSF    -0.214042     0.356107  0.259733     0.528285    -0.162481
# 1stFlrSF       -0.227927     0.403436  0.312843     0.458758    -0.134420
# 2ndFlrSF        0.300366     0.089675  0.059803     0.316624     0.036668
# LowQualFinSF    0.053737     0.007506 -0.001915    -0.039295     0.041877
# GrLivArea       0.086448     0.374251  0.281360     0.599700    -0.065006
# BedroomAbvGr   -0.013283     0.237199  0.117351     0.099639     0.028393
# KitchenAbvGr    0.283506    -0.002729 -0.013075    -0.178220    -0.076047
# TotRmsAbvGrd    0.051179     0.318771  0.184546     0.432579    -0.039952
# Fireplaces     -0.035792     0.230610  0.285983     0.390067    -0.013632
# GarageYrBlt     0.073130     0.055992 -0.034765     0.511482    -0.301881
# GarageCars     -0.027639     0.260252  0.158313     0.596322    -0.161996
# GarageArea     -0.092408     0.322644  0.195162     0.566782    -0.126021
# WoodDeckSF     -0.022609     0.088334  0.216720     0.227137     0.012290
# PoolArea        0.009583     0.196001  0.097107     0.072247    -0.003603
# MiscVal        -0.023503    -0.001329  0.051679    -0.025786     0.075178
# MoSold         -0.016015     0.022517  0.015141     0.090638     0.005519
# YrSold         -0.038595    -0.003885 -0.035399    -0.048759     0.055517
# SalePrice      -0.060775     0.323779  0.249499     0.789185    -0.065642
# BsmtBath        0.006472     0.095161  0.157158     0.095569    -0.019191
# Bath            0.189968     0.168860  0.110328     0.596704    -0.170717
# Total_porch    -0.010369     0.137158  0.074114     0.198544     0.065091
#
#               YearBuilt  YearRemodAdd  MasVnrArea  TotalBsmtSF  1stFlrSF  \
# MSSubClass     0.023988      0.056618    0.027813    -0.214042 -0.227927
# LotFrontage    0.112655      0.088799    0.188758     0.356107  0.403436
# LotArea        0.005506      0.027228    0.121086     0.259733  0.312843
# OverallQual    0.575800      0.555945    0.407230     0.528285  0.458758
# OverallCond   -0.377731      0.080669   -0.137475    -0.162481 -0.134420
# YearBuilt      1.000000      0.592829    0.321905     0.386265  0.279450
# YearRemodAdd   0.592829      1.000000    0.181385     0.280720  0.233384
# MasVnrArea     0.321905      0.181385    1.000000     0.365016  0.337143
# TotalBsmtSF    0.386265      0.280720    0.365016     1.000000  0.813357
# 1stFlrSF       0.279450      0.233384    0.337143     0.813357  1.000000
# 2ndFlrSF       0.011834      0.155102    0.172741    -0.164795 -0.205683
# LowQualFinSF  -0.189044     -0.072526   -0.070515    -0.043845 -0.035870
# GrLivArea      0.198644      0.295048    0.386791     0.461067  0.566049
# BedroomAbvGr  -0.080639     -0.035847    0.091312     0.036237  0.106293
# KitchenAbvGr  -0.167869     -0.139943   -0.037956    -0.065410  0.084392
# TotRmsAbvGrd   0.095476      0.206923    0.278661     0.273895  0.399177
# Fireplaces     0.134313      0.118378    0.242510     0.328241  0.406537
# GarageYrBlt    0.783710      0.615011    0.251293     0.303038  0.213990
# GarageCars     0.525346      0.428325    0.342077     0.423592  0.414905
# GarageArea     0.473216      0.387744    0.365280     0.492980  0.475958
# WoodDeckSF     0.204830      0.197410    0.151579     0.234848  0.235467
# PoolArea       0.006408      0.006874    0.013590     0.139252  0.144006
# MiscVal       -0.030008     -0.001199   -0.027582    -0.005920 -0.010792
# MoSold         0.031754      0.024663    0.013363     0.032920  0.045991
# YrSold        -0.013976      0.033265   -0.013462    -0.030448 -0.028604
# SalePrice      0.514408      0.507831    0.463626     0.595042  0.587642
# BsmtBath       0.159937      0.102927    0.090425     0.301377  0.242569
# Bath           0.507967      0.465321    0.312923     0.256531  0.277762
# Total_porch   -0.123491      0.027897    0.050534     0.148735  0.159069
#
#               2ndFlrSF  LowQualFinSF  GrLivArea  BedroomAbvGr  KitchenAbvGr  \
# MSSubClass    0.300366      0.053737   0.086448     -0.013283      0.283506
# LotFrontage   0.089675      0.007506   0.374251      0.237199     -0.002729
# LotArea       0.059803     -0.001915   0.281360      0.117351     -0.013075
# OverallQual   0.316624     -0.039295   0.599700      0.099639     -0.178220
# OverallCond   0.036668      0.041877  -0.065006      0.028393     -0.076047
# YearBuilt     0.011834     -0.189044   0.198644     -0.080639     -0.167869
# YearRemodAdd  0.155102     -0.072526   0.295048     -0.035847     -0.139943
# MasVnrArea    0.172741     -0.070515   0.386791      0.091312     -0.037956
# TotalBsmtSF  -0.164795     -0.043845   0.461067      0.036237     -0.065410
# 1stFlrSF     -0.205683     -0.035870   0.566049      0.106293      0.084392
# 2ndFlrSF      1.000000      0.046447   0.684802      0.505511      0.040935
# LowQualFinSF  0.046447      1.000000   0.108485      0.099601      0.013767
# GrLivArea     0.684802      0.108485   1.000000      0.509273      0.097929
# BedroomAbvGr  0.505511      0.099601   0.509273      1.000000      0.204218
# KitchenAbvGr  0.040935      0.013767   0.097929      0.204218      1.000000
# TotRmsAbvGrd  0.619871      0.103584   0.821845      0.672542      0.248418
# Fireplaces    0.201345     -0.041799   0.464782      0.100466     -0.113977
# GarageYrBlt   0.057072     -0.031043   0.203051     -0.082016     -0.116131
# GarageCars    0.188522     -0.089494   0.455707      0.058834     -0.043343
# GarageArea    0.135475     -0.063572   0.459261      0.028543     -0.063298
# WoodDeckSF    0.085662     -0.033553   0.242525      0.037998     -0.085037
# PoolArea      0.090189      0.065630   0.188102      0.077270     -0.016128
# MiscVal       0.015327     -0.003564   0.004425      0.015004      0.045887
# MoSold        0.040987     -0.029194   0.065385      0.064584      0.023240
# YrSold       -0.038241     -0.034952  -0.056401     -0.036551     -0.007908
# SalePrice     0.330386     -0.032381   0.707300      0.158281     -0.132108
# BsmtBath     -0.169207     -0.054860   0.033505     -0.139471     -0.046164
# Bath          0.606576     -0.038683   0.707122      0.390453      0.090059
# Total_porch   0.214161      0.078350   0.303716      0.122324     -0.060190
#
#               TotRmsAbvGrd  Fireplaces  GarageYrBlt  GarageCars  GarageArea  \
# MSSubClass        0.051179   -0.035792     0.073130   -0.027639   -0.092408
# LotFrontage       0.318771    0.230610     0.055992    0.260252    0.322644
# LotArea           0.184546    0.285983    -0.034765    0.158313    0.195162
# OverallQual       0.432579    0.390067     0.511482    0.596322    0.566782
# OverallCond      -0.039952   -0.013632    -0.301881   -0.161996   -0.126021
# YearBuilt         0.095476    0.134313     0.783710    0.525346    0.473216
# YearRemodAdd      0.206923    0.118378     0.615011    0.428325    0.387744
# MasVnrArea        0.278661    0.242510     0.251293    0.342077    0.365280
# TotalBsmtSF       0.273895    0.328241     0.303038    0.423592    0.492980
# 1stFlrSF          0.399177    0.406537     0.213990    0.414905    0.475958
# 2ndFlrSF          0.619871    0.201345     0.057072    0.188522    0.135475
# LowQualFinSF      0.103584   -0.041799    -0.031043   -0.089494   -0.063572
# GrLivArea         0.821845    0.464782     0.203051    0.455707    0.459261
# BedroomAbvGr      0.672542    0.100466    -0.082016    0.058834    0.028543
# KitchenAbvGr      0.248418   -0.113977    -0.116131   -0.043343   -0.063298
# TotRmsAbvGrd      1.000000    0.329297     0.119523    0.348490    0.323087
# Fireplaces        0.329297    1.000000     0.037981    0.281100    0.252903
# GarageYrBlt       0.119523    0.037981     1.000000    0.482221    0.479034
# GarageCars        0.348490    0.281100     0.482221    1.000000    0.877542
# GarageArea        0.323087    0.252903     0.479034    0.877542    1.000000
# WoodDeckSF        0.153871    0.177070     0.216256    0.213252    0.215972
# PoolArea          0.094082    0.104895    -0.015092    0.022504    0.066697
# MiscVal           0.030337    0.010342    -0.035198   -0.035777   -0.018672
# MoSold            0.058427    0.065136     0.003303    0.080790    0.057009
# YrSold           -0.060971   -0.025018    -0.011098   -0.057866   -0.037036
# SalePrice         0.528363    0.459611     0.458007    0.628329    0.619000
# BsmtBath         -0.060544    0.148061     0.086593    0.101820    0.162821
# Bath              0.607867    0.280562     0.476537    0.492209    0.417374
# Total_porch       0.206284    0.197559    -0.054463    0.089565    0.127460
#
#               WoodDeckSF  PoolArea   MiscVal    MoSold    YrSold  SalePrice  \
# MSSubClass     -0.022609  0.009583 -0.023503 -0.016015 -0.038595  -0.060775
# LotFrontage     0.088334  0.196001 -0.001329  0.022517 -0.003885   0.323779
# LotArea         0.216720  0.097107  0.051679  0.015141 -0.035399   0.249499
# OverallQual     0.227137  0.072247 -0.025786  0.090638 -0.048759   0.789185
# OverallCond     0.012290 -0.003603  0.075178  0.005519  0.055517  -0.065642
# YearBuilt       0.204830  0.006408 -0.030008  0.031754 -0.013976   0.514408
# YearRemodAdd    0.197410  0.006874 -0.001199  0.024663  0.033265   0.507831
# MasVnrArea      0.151579  0.013590 -0.027582  0.013363 -0.013462   0.463626
# TotalBsmtSF     0.234848  0.139252 -0.005920  0.032920 -0.030448   0.595042
# 1stFlrSF        0.235467  0.144006 -0.010792  0.045991 -0.028604   0.587642
# 2ndFlrSF        0.085662  0.090189  0.015327  0.040987 -0.038241   0.330386
# LowQualFinSF   -0.033553  0.065630 -0.003564 -0.029194 -0.034952  -0.032381
# GrLivArea       0.242525  0.188102  0.004425  0.065385 -0.056401   0.707300
# BedroomAbvGr    0.037998  0.077270  0.015004  0.064584 -0.036551   0.158281
# KitchenAbvGr   -0.085037 -0.016128  0.045887  0.023240 -0.007908  -0.132108
# TotRmsAbvGrd    0.153871  0.094082  0.030337  0.058427 -0.060971   0.528363
# Fireplaces      0.177070  0.104895  0.010342  0.065136 -0.025018   0.459611
# GarageYrBlt     0.216256 -0.015092 -0.035198  0.003303 -0.011098   0.458007
# GarageCars      0.213252  0.022504 -0.035777  0.080790 -0.057866   0.628329
# GarageArea      0.215972  0.066697 -0.018672  0.057009 -0.037036   0.619000
# WoodDeckSF      1.000000  0.080366 -0.006860  0.009254  0.030975   0.315444
# PoolArea        0.080366  1.000000  0.029771 -0.038624 -0.066063   0.103280
# MiscVal        -0.006860  0.029771  1.000000 -0.008773 -0.008439  -0.013071
# MoSold          0.009254 -0.038624 -0.008773  1.000000 -0.144536   0.072764
# YrSold          0.030975 -0.066063 -0.008439 -0.144536  1.000000  -0.045508
# SalePrice       0.315444  0.103280 -0.013071  0.072764 -0.045508   1.000000
# BsmtBath        0.174821  0.081178 -0.026693 -0.003850  0.049040   0.212186
# Bath            0.194862  0.058215 -0.009674  0.057833 -0.038629   0.601862
# Total_porch    -0.089134  0.104407  0.019490  0.044134 -0.031671   0.212832
#
#               BsmtBath      Bath  Total_porch
# MSSubClass    0.006472  0.189968    -0.010369
# LotFrontage   0.095161  0.168860     0.137158
# LotArea       0.157158  0.110328     0.074114
# OverallQual   0.095569  0.596704     0.198544
# OverallCond  -0.019191 -0.170717     0.065091
# YearBuilt     0.159937  0.507967    -0.123491
# YearRemodAdd  0.102927  0.465321     0.027897
# MasVnrArea    0.090425  0.312923     0.050534
# TotalBsmtSF   0.301377  0.256531     0.148735
# 1stFlrSF      0.242569  0.277762     0.159069
# 2ndFlrSF     -0.169207  0.606576     0.214161
# LowQualFinSF -0.054860 -0.038683     0.078350
# GrLivArea     0.033505  0.707122     0.303716
# BedroomAbvGr -0.139471  0.390453     0.122324
# KitchenAbvGr -0.046164  0.090059    -0.060190
# TotRmsAbvGrd -0.060544  0.607867     0.206284
# Fireplaces    0.148061  0.280562     0.197559
# GarageYrBlt   0.086593  0.476537    -0.054463
# GarageCars    0.101820  0.492209     0.089565
# GarageArea    0.162821  0.417374     0.127460
# WoodDeckSF    0.174821  0.194862    -0.089134
# PoolArea      0.081178  0.058215     0.104407
# MiscVal      -0.026693 -0.009674     0.019490
# MoSold       -0.003850  0.057833     0.044134
# YrSold        0.049040 -0.038629    -0.031671
# SalePrice     0.212186  0.601862     0.212832
# BsmtBath      1.000000 -0.076571     0.019568
# Bath         -0.076571  1.000000     0.159840
# Total_porch   0.019568  0.159840     1.000000

# %%
plt.figure(figsize=(30,25))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
non_cat_columns = ['LotArea','YearBuilt','YearRemodAdd','MasVnrArea',
                  'TotalBsmtSF','1stFlrSF','2ndFlrSF','LowQualFinSF',
                  'GarageYrBlt','PoolArea','MoSold','YrSold','MiscVal',
                  'SalePrice']

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# #### Skewness

# %%
for i in non_cat_columns:
    s = df[i].skew()
    print(i,s)
# Out:
# LotArea 10.659284548299626
# YearBuilt -0.5792035025736898
# YearRemodAdd -0.49586353822203716
# MasVnrArea 2.8346577812934406
# TotalBsmtSF 1.7445908855423957
# 1stFlrSF 1.5137072331415693
# 2ndFlrSF 0.8234785103609108
# LowQualFinSF 8.666142302049042
# GarageYrBlt -0.6629343832202744
# PoolArea 13.243710763499866
# MoSold 0.22097863147453375
# YrSold 0.1157647118679818
# MiscVal 23.065942802581013
# SalePrice 1.953877705368286

# %%
df[i].plot(kind ='density',subplots = True ,layout = (5,6),figsize=(28,20),sharex=False)
plt.show()

# %% [markdown]
# ### Data Conversion

# %%
from sklearn.preprocessing import LabelEncoder
lec = LabelEncoder()

# %%
for i in df.columns:
    if df[i].dtypes == object:
        df[i] = lec.fit_transform(df[i])

# %%
df.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  LandContour  \
# 0         120         3     70.98847     4928       1         0            3
# 1          20         3     95.00000    15865       1         0            3
# 2          60         3     92.00000     9920       1         0            3
# 3          20         3    105.00000    11751       1         0            3
# 4          20         3     70.98847    16635       1         0            3
#
#    Utilities  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# 0          0          4          0            13           2           2
# 1          0          4          1            12           2           2
# 2          0          1          0            15           2           2
# 3          0          4          0            14           2           2
# 4          0          2          0            14           2           2
#
#    BldgType  HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0         4           2            6            5       1976          1976
# 1         0           2            8            6       1970          1970
# 2         0           5            7            5       1996          1997
# 3         0           2            6            6       1977          1977
# 4         0           2            6            7       1977          2000
#
#    RoofStyle  RoofMatl  Exterior1st  Exterior2nd  MasVnrType  MasVnrArea  \
# 0          1         1            8            9           3         0.0
# 1          0         5           12           13           3         0.0
# 2          1         1            7            7           3         0.0
# 3          3         1            8            9           1       480.0
# 4          1         1            4            4           4       126.0
#
#    ExterQual  ExterCond  Foundation  BsmtQual  BsmtCond  BsmtExposure  \
# 0          3          4           1         2         4             4
# 1          2          2           2         4         1             1
# 2          2          4           2         2         4             0
# 3          3          4           1         2         4             4
# 4          2          4           1         2         4             4
#
#    BsmtFinType1  BsmtFinType2  TotalBsmtSF  Heating  HeatingQC  CentralAir  \
# 0             0             6         1078        1          4           1
# 1             0             5         2217        1          0           1
# 2             2             6         1117        1          0           1
# 3             1             6         1844        1          0           1
# 4             0             6         1602        1          2           1
#
#    Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BedroomAbvGr  \
# 0           4       958         0             0        958             2
# 1           4      2217         0             0       2217             4
# 2           4      1127       886             0       2013             3
# 3           4      1844         0             0       1844             3
# 4           4      1602         0             0       1602             3
#
#    KitchenAbvGr  KitchenQual  TotRmsAbvGrd  Functional  Fireplaces  \
# 0             1            3             5           6           1
# 1             1            2             8           6           1
# 2             1            3             8           6           1
# 3             1            3             7           6           1
# 4             1            2             8           6           1
#
#    FireplaceQu  GarageType  GarageYrBlt  GarageFinish  GarageCars  GarageArea  \
# 0            5           1       1977.0             2           2         440
# 1            5           1       1970.0             3           2         621
# 2            5           1       1997.0             3           2         455
# 3            5           1       1977.0             2           2         546
# 4            5           1       1977.0             0           2         529
#
#    GarageQual  GarageCond  PavedDrive  WoodDeckSF  PoolArea  MiscVal  MoSold  \
# 0           5           5           2           0         0        0       2
# 1           5           5           2          81         0        0      10
# 2           5           5           2         180         0        0       6
# 3           5           5           2           0         0        0       1
# 4           5           5           2         240         0        0       6
#
#    YrSold  SaleType  SaleCondition  SalePrice  BsmtBath  Bath  Total_porch
# 0    2007         8              4     128000       0.0   2.0          205
# 1    2007         8              4     268000       1.0   2.0          431
# 2    2007         8              4     269790       1.0   2.5          130
# 3    2010         0              4     190000       0.0   2.0          122
# 4    2009         8              4     215000       0.5   2.0            0

# %% [markdown]
# ### Checking Outliers

# %%
df_non_cat_columns = df[non_cat_columns]
df_non_cat_columns.head()
# Out:
#    LotArea  YearBuilt  YearRemodAdd  MasVnrArea  TotalBsmtSF  1stFlrSF  \
# 0     4928       1976          1976         0.0         1078       958
# 1    15865       1970          1970         0.0         2217      2217
# 2     9920       1996          1997         0.0         1117      1127
# 3    11751       1977          1977       480.0         1844      1844
# 4    16635       1977          2000       126.0         1602      1602
#
#    2ndFlrSF  LowQualFinSF  GarageYrBlt  PoolArea  MoSold  YrSold  MiscVal  \
# 0         0             0       1977.0         0       2    2007        0
# 1         0             0       1970.0         0      10    2007        0
# 2       886             0       1997.0         0       6    2007        0
# 3         0             0       1977.0         0       1    2010        0
# 4         0             0       1977.0         0       6    2009        0
#
#    SalePrice
# 0     128000
# 1     268000
# 2     269790
# 3     190000
# 4     215000

# %%
df_non_cat_columns.plot(kind = 'box',subplots=True,layout=(5,3),figsize=(25,20))
plt.show()

# %% [markdown]
# ###### We can see that Outliers are present in;
#
# LotArea
#
# YearBuilt
#
# MasVnrArea
#
# TotalBsmtSF
#
# 1stFlrSF
#
# 2ndFlrSF
#
# LowQualFinSF
#
# GaragYrBuilt
#
# PoolArea
#
# MiscVal
#
# SalePrice

# %% [markdown]
# ### Removing Outliers

# %% [markdown]
# #### IQR Technique

# %%
for i in non_cat_columns:
    Q1 = df[i].quantile(0.25)
    Q3 = df[i].quantile(0.75)
    IQR = Q3 - Q1

    lower_limit = Q1 - 1.5 * IQR
    upper_limit = Q3 + 1.5 * IQR

    df_1 = df[(df[i] > lower_limit) & (df[i] < upper_limit)]
df_1.shape
# Out:
# (1123, 68)

# %%
df_1.shape
# Out:
# (1123, 68)

# %% [markdown]
# ### VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def calculate_vif(dataset):
    vif = pd.DataFrame()
    vif['Features'] = dataset.columns
    vif['VIF_Values'] = [variance_inflation_factor(dataset.values,i) for i in range(dataset.shape[1])]
    return(vif.sort_values(by='VIF_Values',ascending = False))

# %%
calculate_vif(df_non_cat_columns)
# Out:
#         Features    VIF_Values
# 8    GarageYrBlt  19947.275627
# 2   YearRemodAdd  17291.653215
# 11        YrSold  14694.006181
# 1      YearBuilt  14126.123355
# 5       1stFlrSF     37.074900
# 4    TotalBsmtSF     22.859709
# 13     SalePrice     21.399510
# 10        MoSold      6.656332
# 6       2ndFlrSF      2.858916
# 0        LotArea      2.749844
# 3     MasVnrArea      1.791215
# 7   LowQualFinSF      1.105817
# 9       PoolArea      1.066824
# 12       MiscVal      1.014211

# %%
df_1.drop(['GarageYrBlt','YearRemodAdd','YrSold','YearBuilt','1stFlrSF','TotalBsmtSF'],axis=1,inplace=True)

# %%
df_1.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  LandContour  \
# 0         120         3     70.98847     4928       1         0            3
# 1          20         3     95.00000    15865       1         0            3
# 2          60         3     92.00000     9920       1         0            3
# 3          20         3    105.00000    11751       1         0            3
# 4          20         3     70.98847    16635       1         0            3
#
#    Utilities  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# 0          0          4          0            13           2           2
# 1          0          4          1            12           2           2
# 2          0          1          0            15           2           2
# 3          0          4          0            14           2           2
# 4          0          2          0            14           2           2
#
#    BldgType  HouseStyle  OverallQual  OverallCond  RoofStyle  RoofMatl  \
# 0         4           2            6            5          1         1
# 1         0           2            8            6          0         5
# 2         0           5            7            5          1         1
# 3         0           2            6            6          3         1
# 4         0           2            6            7          1         1
#
#    Exterior1st  Exterior2nd  MasVnrType  MasVnrArea  ExterQual  ExterCond  \
# 0            8            9           3         0.0          3          4
# 1           12           13           3         0.0          2          2
# 2            7            7           3         0.0          2          4
# 3            8            9           1       480.0          3          4
# 4            4            4           4       126.0          2          4
#
#    Foundation  BsmtQual  BsmtCond  BsmtExposure  BsmtFinType1  BsmtFinType2  \
# 0           1         2         4             4             0             6
# 1           2         4         1             1             0             5
# 2           2         2         4             0             2             6
# 3           1         2         4             4             1             6
# 4           1         2         4             4             0             6
#
#    Heating  HeatingQC  CentralAir  Electrical  2ndFlrSF  LowQualFinSF  \
# 0        1          4           1           4         0             0
# 1        1          0           1           4         0             0
# 2        1          0           1           4       886             0
# 3        1          0           1           4         0             0
# 4        1          2           1           4         0             0
#
#    GrLivArea  BedroomAbvGr  KitchenAbvGr  KitchenQual  TotRmsAbvGrd  \
# 0        958             2             1            3             5
# 1       2217             4             1            2             8
# 2       2013             3             1            3             8
# 3       1844             3             1            3             7
# 4       1602             3             1            2             8
#
#    Functional  Fireplaces  FireplaceQu  GarageType  GarageFinish  GarageCars  \
# 0           6           1            5           1             2           2
# 1           6           1            5           1             3           2
# 2           6           1            5           1             3           2
# 3           6           1            5           1             2           2
# 4           6           1            5           1             0           2
#
#    GarageArea  GarageQual  GarageCond  PavedDrive  WoodDeckSF  PoolArea  \
# 0         440           5           5           2           0         0
# 1         621           5           5           2          81         0
# 2         455           5           5           2         180         0
# 3         546           5           5           2           0         0
# 4         529           5           5           2         240         0
#
#    MiscVal  MoSold  SaleType  SaleCondition  SalePrice  BsmtBath  Bath  \
# 0        0       2         8              4     128000       0.0   2.0
# 1        0      10         8              4     268000       1.0   2.0
# 2        0       6         8              4     269790       1.0   2.5
# 3        0       1         0              4     190000       0.0   2.0
# 4        0       6         8              4     215000       0.5   2.0
#
#    Total_porch
# 0          205
# 1          431
# 2          130
# 3          122
# 4            0

# %%
df_1.shape
# Out:
# (1123, 62)

# %% [markdown]
# ### Splitting Data into x and y

# %%
x = df_1.drop('SalePrice',axis=1)
x.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  LandContour  \
# 0         120         3     70.98847     4928       1         0            3
# 1          20         3     95.00000    15865       1         0            3
# 2          60         3     92.00000     9920       1         0            3
# 3          20         3    105.00000    11751       1         0            3
# 4          20         3     70.98847    16635       1         0            3
#
#    Utilities  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# 0          0          4          0            13           2           2
# 1          0          4          1            12           2           2
# 2          0          1          0            15           2           2
# 3          0          4          0            14           2           2
# 4          0          2          0            14           2           2
#
#    BldgType  HouseStyle  OverallQual  OverallCond  RoofStyle  RoofMatl  \
# 0         4           2            6            5          1         1
# 1         0           2            8            6          0         5
# 2         0           5            7            5          1         1
# 3         0           2            6            6          3         1
# 4         0           2            6            7          1         1
#
#    Exterior1st  Exterior2nd  MasVnrType  MasVnrArea  ExterQual  ExterCond  \
# 0            8            9           3         0.0          3          4
# 1           12           13           3         0.0          2          2
# 2            7            7           3         0.0          2          4
# 3            8            9           1       480.0          3          4
# 4            4            4           4       126.0          2          4
#
#    Foundation  BsmtQual  BsmtCond  BsmtExposure  BsmtFinType1  BsmtFinType2  \
# 0           1         2         4             4             0             6
# 1           2         4         1             1             0             5
# 2           2         2         4             0             2             6
# 3           1         2         4             4             1             6
# 4           1         2         4             4             0             6
#
#    Heating  HeatingQC  CentralAir  Electrical  2ndFlrSF  LowQualFinSF  \
# 0        1          4           1           4         0             0
# 1        1          0           1           4         0             0
# 2        1          0           1           4       886             0
# 3        1          0           1           4         0             0
# 4        1          2           1           4         0             0
#
#    GrLivArea  BedroomAbvGr  KitchenAbvGr  KitchenQual  TotRmsAbvGrd  \
# 0        958             2             1            3             5
# 1       2217             4             1            2             8
# 2       2013             3             1            3             8
# 3       1844             3             1            3             7
# 4       1602             3             1            2             8
#
#    Functional  Fireplaces  FireplaceQu  GarageType  GarageFinish  GarageCars  \
# 0           6           1            5           1             2           2
# 1           6           1            5           1             3           2
# 2           6           1            5           1             3           2
# 3           6           1            5           1             2           2
# 4           6           1            5           1             0           2
#
#    GarageArea  GarageQual  GarageCond  PavedDrive  WoodDeckSF  PoolArea  \
# 0         440           5           5           2           0         0
# 1         621           5           5           2          81         0
# 2         455           5           5           2         180         0
# 3         546           5           5           2           0         0
# 4         529           5           5           2         240         0
#
#    MiscVal  MoSold  SaleType  SaleCondition  BsmtBath  Bath  Total_porch
# 0        0       2         8              4       0.0   2.0          205
# 1        0      10         8              4       1.0   2.0          431
# 2        0       6         8              4       1.0   2.5          130
# 3        0       1         0              4       0.0   2.0          122
# 4        0       6         8              4       0.5   2.0            0

# %%
y = df_1['SalePrice']
y.shape
# Out:
# (1123,)

# %%
x.shape
# Out:
# (1123, 61)

# %% [markdown]
# ### Normalizing Data using Power Transform

# %%
from sklearn.preprocessing import power_transform
x1 = power_transform(x)

# %%
type(x1)
# Out:
# numpy.ndarray

# %%
x = pd.DataFrame(x1,columns=x.columns)
x.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage   LotArea    Street  LotShape  \
# 0    1.358585 -0.162767     0.126036 -1.189163  0.059788 -1.382952
# 1   -1.173334 -0.162767     1.165689  1.145932  0.059788 -1.382952
# 2    0.478824 -0.162767     1.045310  0.193635  0.059788 -1.382952
# 3   -1.173334 -0.162767     1.550964  0.534889  0.059788 -1.382952
# 4   -1.173334 -0.162767     0.126036  1.243147  0.059788 -1.382952
#
#    LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0     0.339314        0.0   0.617941  -0.239664      0.232633     0.05714
# 1     0.339314        0.0   0.617941   4.172510      0.072468     0.05714
# 2     0.339314        0.0  -1.477878  -0.239664      0.543860     0.05714
# 3     0.339314        0.0   0.617941  -0.239664      0.389676     0.05714
# 4     0.339314        0.0  -1.020007  -0.239664      0.389676     0.05714
#
#    Condition2  BldgType  HouseStyle  OverallQual  OverallCond  RoofStyle  \
# 0    0.009613  2.274411   -0.447968     0.001923    -0.508270  -0.360859
# 1    0.009613 -0.444037   -0.447968     1.555660     0.391701  -5.102431
# 2    0.009613 -0.444037    1.024317     0.777647    -0.508270  -0.360859
# 3    0.009613 -0.444037   -0.447968     0.001923     0.391701   1.802257
# 4    0.009613 -0.444037   -0.447968     0.001923     1.215644  -0.360859
#
#    RoofMatl  Exterior1st  Exterior2nd  MasVnrType  MasVnrArea  ExterQual  \
# 0 -0.081808    -0.316981    -0.202032    0.490601   -0.798607   0.750149
# 1  5.689272     1.163799     1.125069    0.490601   -0.798607  -1.257826
# 2 -0.081808    -0.638180    -0.774928    0.490601   -0.798607  -1.257826
# 3 -0.081808    -0.316981    -0.202032   -1.373758    1.416250   0.750149
# 4 -0.081808    -1.466671    -1.500917    1.841101    1.197155  -1.257826
#
#    ExterCond  Foundation  BsmtQual  BsmtCond  BsmtExposure  BsmtFinType1  \
# 0   0.381988   -0.520215 -0.747144  0.350647      0.689839     -1.580142
# 1  -2.618189    0.877159  1.020658 -2.866627     -1.444597     -1.580142
# 2   0.381988    0.877159 -0.747144  0.350647     -1.714505     -0.392990
# 3   0.381988   -0.520215 -0.747144  0.350647      0.689839     -0.917282
# 4   0.381988   -0.520215 -0.747144  0.350647      0.689839     -1.580142
#
#    BsmtFinType2   Heating  HeatingQC  CentralAir  Electrical  2ndFlrSF  \
# 0      0.411980 -0.094911   1.208812    0.273205    0.309159 -0.867794
# 1     -1.860866 -0.094911  -0.997654    0.273205    0.309159 -0.867794
# 2      0.411980 -0.094911  -0.997654    0.273205    0.309159  1.184176
# 3      0.411980 -0.094911  -0.997654    0.273205    0.309159 -0.867794
# 4      0.411980 -0.094911   0.600907    0.273205    0.309159 -0.867794
#
#    LowQualFinSF  GrLivArea  BedroomAbvGr  KitchenAbvGr  KitchenQual  \
# 0     -0.141357  -1.218433     -1.099946     -0.172942     0.927631
# 1     -0.141357   1.424971      1.376057     -0.172942    -0.802635
# 2     -0.141357   1.112064      0.164480     -0.172942     0.927631
# 3     -0.141357   0.829825      0.164480     -0.172942     0.927631
# 4     -0.141357   0.380990      0.164480     -0.172942    -0.802635
#
#    TotRmsAbvGrd  Functional  Fireplaces  FireplaceQu  GarageType  \
# 0     -0.962104     0.28249    0.834818     1.572988   -0.785602
# 1      1.025216     0.28249    0.834818     1.572988   -0.785602
# 2      1.025216     0.28249    0.834818     1.572988   -0.785602
# 3      0.434367     0.28249    0.834818     1.572988   -0.785602
# 4      1.025216     0.28249    0.834818     1.572988   -0.785602
#
#    GarageFinish  GarageCars  GarageArea  GarageQual  GarageCond  PavedDrive  \
# 0     -0.088898    0.332004   -0.062973    0.341013    0.324504    0.307475
# 1      0.975454    0.332004    0.761949    0.341013    0.324504    0.307475
# 2      0.975454    0.332004    0.007315    0.341013    0.324504    0.307475
# 3     -0.088898    0.332004    0.425860    0.341013    0.324504    0.307475
# 4     -1.569815    0.332004    0.348626    0.341013    0.324504    0.307475
#
#    WoodDeckSF  PoolArea   MiscVal    MoSold  SaleType  SaleCondition  \
# 0   -0.936761 -0.073291 -0.197111 -1.722578  0.381639       0.067992
# 1    0.829455 -0.073291 -0.197111  1.323085  0.381639       0.067992
# 2    1.076693 -0.073291 -0.197111 -0.067412  0.381639       0.067992
# 3   -0.936761 -0.073291 -0.197111 -2.222487 -2.904934       0.067992
# 4    1.161684 -0.073291 -0.197111 -0.067412  0.381639       0.067992
#
#    BsmtBath      Bath  Total_porch
# 0 -0.894534  0.489357     1.115593
# 1  1.140070  0.489357     1.690087
# 2  1.140070  1.215668     0.802012
# 3 -0.894534  0.489357     0.760450
# 4  0.492868  0.489357    -1.311905

# %% [markdown]
# ## Test Data

# %%
df_2 = pd.read_csv('test.housing.csv')
df_2.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL         86.0    14157   Pave   NaN      IR1
# 1  1018         120       RL          NaN     5814   Pave   NaN      IR1
# 2   929          20       RL          NaN    11838   Pave   NaN      Reg
# 3  1148          70       RL         75.0    12000   Pave   NaN      Reg
# 4  1227          60       RL         86.0    14598   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         HLS    AllPub    Corner       Gtl      StoneBr       Norm
# 1         Lvl    AllPub   CulDSac       Gtl      StoneBr       Norm
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Bnk    AllPub    Inside       Gtl      Crawfor       Norm
# 4         Lvl    AllPub   CulDSac       Gtl      Somerst      Feedr
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     1Story            9            5       2005
# 1       Norm   TwnhsE     1Story            8            5       1984
# 2       Norm     1Fam     1Story            8            5       2001
# 3       Norm     1Fam     2Story            7            7       1941
# 4       Norm     1Fam     2Story            6            5       2007
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2006       Hip  CompShg     VinylSd     VinylSd      Stone
# 1          1984     Gable  CompShg     HdBoard     HdBoard       None
# 2          2001       Hip  CompShg     VinylSd     VinylSd       None
# 3          1950     Gable  CompShg     MetalSd     MetalSd       None
# 4          2007     Gable  CompShg     VinylSd     VinylSd      Stone
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       200.0        Gd        TA      PConc       Ex       TA           Gd
# 1         0.0        Gd        TA     CBlock       Gd       TA           Av
# 2         0.0        Gd        TA      PConc       Gd       TA           Av
# 3         0.0        TA        TA     CBlock       TA       TA           No
# 4        74.0        Gd        TA      PConc       Gd       TA           Mn
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ        1249          Unf           0        673         1922
# 1          GLQ        1036          Unf           0        184         1220
# 2          Unf           0          Unf           0       1753         1753
# 3          Rec         275          Unf           0        429          704
# 4          Unf           0          Unf           0        894          894
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr      1922         0             0
# 1    GasA        Gd          Y      SBrkr      1360         0             0
# 2    GasA        Ex          Y      SBrkr      1788         0             0
# 3    GasA        Ex          Y      SBrkr       860       704             0
# 4    GasA        Ex          Y      SBrkr       894      1039             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1922             1             0         2         0             3
# 1       1360             1             0         1         0             1
# 2       1788             0             0         2         0             3
# 3       1564             0             0         1         1             3
# 4       1933             0             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           1          Gd
# 1             1          Gd             4        Typ           1          Ex
# 2             1          Ex             7        Typ           1          TA
# 3             1          Fa             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          Gd
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2005.0          Fin           3         676         TA
# 1     Attchd       1984.0          RFn           2         565         TA
# 2     Attchd       2001.0          RFn           2         522         TA
# 3     Attchd       1941.0          Unf           1         234         TA
# 4    BuiltIn       2007.0          Fin           3         668         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y         178           51              0          0
# 1         TA          Y          63            0              0          0
# 2         TA          Y         202          151              0          0
# 3         TA          Y           0            0              0          0
# 4         TA          Y         100           18              0          0
#
#    ScreenPorch  PoolArea  PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0     NaN   NaN         NaN        0       7    2007
# 1            0         0     NaN   NaN         NaN        0       8    2009
# 2            0         0     NaN   NaN         NaN        0       6    2009
# 3            0         0     NaN   NaN         NaN        0       7    2009
# 4            0         0     NaN   NaN         NaN        0       1    2008
#
#   SaleType SaleCondition
# 0       WD        Normal
# 1      COD       Abnorml
# 2       WD        Normal
# 3       WD        Normal
# 4       WD        Normal

# %%
df_2.shape
# Out:
# (292, 80)

# %% [markdown]
# ###### In test dataset we have 292 rows and  80.

# %%
for i in df_2.columns:
    if df_2[i].isnull().sum()>0:
        print(i,df_2[i].isnull().sum())
# Out:
# LotFrontage 45
# Alley 278
# MasVnrType 1
# MasVnrArea 1
# BsmtQual 7
# BsmtCond 7
# BsmtExposure 7
# BsmtFinType1 7
# BsmtFinType2 7
# Electrical 1
# FireplaceQu 139
# GarageType 17
# GarageYrBlt 17
# GarageFinish 17
# GarageQual 17
# GarageCond 17
# PoolQC 292
# Fence 248
# MiscFeature 282

# %%
df_2.drop(['Id','Alley','PoolQC','Fence','MiscFeature'],axis=1,inplace=True)

# %% [markdown]
# ### Analyzing the Data

# %%
df_2.drop(['BsmtFinSF1','BsmtFinSF2','BsmtUnfSF'],axis=1,inplace=True)

# %%
df_2['BsmtHalfBath'] = 0.5 * df_2['BsmtHalfBath']
df_2['HalfBath'] = 0.5 * df_2['HalfBath']

# %%
df_2['BsmtBath'] = df_2['BsmtHalfBath'] + df_2['BsmtFullBath']
df_2['Bath'] = df_2['HalfBath'] + df_2['FullBath']

# %%
df_2.drop(['BsmtFullBath','BsmtHalfBath','FullBath','HalfBath'],axis=1,inplace=True)

# %%
df_2['Total_porch'] = df_2['OpenPorchSF'] + df_2['EnclosedPorch'] + df_2['3SsnPorch'] + df_2['ScreenPorch']

# %% [markdown]
# ### Handling Missing values

# %%
df_2['LotFrontage'] = df_2['LotFrontage'].fillna(df['LotFrontage'].mean())

# %%
df_2['MasVnrType'] = df_2['MasVnrType'].fillna('NA')
df_2['MasVnrArea'] = df_2['MasVnrArea'].fillna(df_2['MasVnrArea'].mean())

# %%
df_2['BsmtQual'] = df_2['BsmtQual'].fillna('NA')
df_2['BsmtCond'] = df_2['BsmtCond'].fillna('NA')
df_2['BsmtExposure'] = df_2['BsmtExposure'].fillna('NA')
df_2['BsmtFinType1'] = df_2['BsmtFinType1'].fillna('NA')
df_2['BsmtFinType2'] = df_2['BsmtFinType2'].fillna('NA')

# %%
df['FireplaceQu'] = df['FireplaceQu'].fillna('NA')
df['GarageType'] = df['GarageType'].fillna('NA')
df['GarageFinish'] = df['GarageFinish'].fillna('NA')
df['GarageQual'] = df['GarageQual'].fillna('NA')
df['GarageCond'] = df['GarageCond'].fillna('NA')

# %%
df['GarageYrBlt'] = df['GarageYrBlt'].fillna(df['GarageYrBlt'].mean())

# %%
df_2.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          20       RL     86.00000    14157   Pave      IR1         HLS
# 1         120       RL     70.98847     5814   Pave      IR1         Lvl
# 2          20       RL     70.98847    11838   Pave      Reg         Lvl
# 3          70       RL     75.00000    12000   Pave      Reg         Bnk
# 4          60       RL     86.00000    14598   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Corner       Gtl      StoneBr       Norm       Norm     1Fam
# 1    AllPub   CulDSac       Gtl      StoneBr       Norm       Norm   TwnhsE
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Inside       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub   CulDSac       Gtl      Somerst      Feedr       Norm     1Fam
#
#   HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# 0     1Story            9            5       2005          2006       Hip
# 1     1Story            8            5       1984          1984     Gable
# 2     1Story            8            5       2001          2001       Hip
# 3     2Story            7            7       1941          1950     Gable
# 4     2Story            6            5       2007          2007     Gable
#
#   RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond  \
# 0  CompShg     VinylSd     VinylSd      Stone       200.0        Gd        TA
# 1  CompShg     HdBoard     HdBoard       None         0.0        Gd        TA
# 2  CompShg     VinylSd     VinylSd       None         0.0        Gd        TA
# 3  CompShg     MetalSd     MetalSd       None         0.0        TA        TA
# 4  CompShg     VinylSd     VinylSd      Stone        74.0        Gd        TA
#
#   Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2  \
# 0      PConc       Ex       TA           Gd          GLQ          Unf
# 1     CBlock       Gd       TA           Av          GLQ          Unf
# 2      PConc       Gd       TA           Av          Unf          Unf
# 3     CBlock       TA       TA           No          Rec          Unf
# 4      PConc       Gd       TA           Mn          Unf          Unf
#
#    TotalBsmtSF Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  \
# 0         1922    GasA        Ex          Y      SBrkr      1922         0
# 1         1220    GasA        Gd          Y      SBrkr      1360         0
# 2         1753    GasA        Ex          Y      SBrkr      1788         0
# 3          704    GasA        Ex          Y      SBrkr       860       704
# 4          894    GasA        Ex          Y      SBrkr       894      1039
#
#    LowQualFinSF  GrLivArea  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 0             0       1922             3             1          Gd
# 1             0       1360             1             1          Gd
# 2             0       1788             3             1          Ex
# 3             0       1564             3             1          Fa
# 4             0       1933             4             1          Gd
#
#    TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 0             8        Typ           1          Gd     Attchd       2005.0
# 1             4        Typ           1          Ex     Attchd       1984.0
# 2             7        Typ           1          TA     Attchd       2001.0
# 3             7        Typ           1          Gd     Attchd       1941.0
# 4             9        Typ           1          Gd    BuiltIn       2007.0
#
#   GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 0          Fin           3         676         TA         TA          Y
# 1          RFn           2         565         TA         TA          Y
# 2          RFn           2         522         TA         TA          Y
# 3          Unf           1         234         TA         TA          Y
# 4          Fin           3         668         TA         TA          Y
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# 0         178           51              0          0            0         0
# 1          63            0              0          0            0         0
# 2         202          151              0          0            0         0
# 3           0            0              0          0            0         0
# 4         100           18              0          0            0         0
#
#    MiscVal  MoSold  YrSold SaleType SaleCondition  BsmtBath  Bath  Total_porch
# 0        0       7    2007       WD        Normal       1.0   2.0           51
# 1        0       8    2009      COD       Abnorml       1.0   1.0            0
# 2        0       6    2009       WD        Normal       0.0   2.0          151
# 3        0       7    2009       WD        Normal       0.0   1.5            0
# 4        0       1    2008       WD        Normal       0.0   2.5           18

# %%
df_2.shape
# Out:
# (292, 71)

# %%
df_2.drop(['GarageYrBlt','YearRemodAdd','YrSold','YearBuilt','1stFlrSF','TotalBsmtSF'],axis=1,inplace=True)

# %% [markdown]
# ###### We dropped these column because in training data we had to dropped that columns.

# %%
df_2.drop(['OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch'],axis=1,inplace=True)

# %%
df_2.shape
# Out:
# (292, 61)

# %% [markdown]
# ###### We fill all the missing values and dropped the unnecessary columns in testing data.

# %% [markdown]
# ### Data Conversion

# %%
from sklearn.preprocessing import LabelEncoder
lec = LabelEncoder()

# %%
for i in df_2.columns:
    if df_2[i].dtypes == object:
        df_2[i] = lec.fit_transform(df_2[i])

# %%
df_2.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  LandContour  \
# 0          20         2     86.00000    14157       1         0            1
# 1         120         2     70.98847     5814       1         0            3
# 2          20         2     70.98847    11838       1         3            3
# 3          70         2     75.00000    12000       1         3            0
# 4          60         2     86.00000    14598       1         0            3
#
#    Utilities  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# 0          0          0          0            21           2           0
# 1          0          1          0            21           2           0
# 2          0          4          0             4           2           0
# 3          0          4          0             5           2           0
# 4          0          1          0            20           1           0
#
#    BldgType  HouseStyle  OverallQual  OverallCond  RoofStyle  RoofMatl  \
# 0         0           2            9            5          3         0
# 1         4           2            8            5          1         0
# 2         0           2            8            5          3         0
# 3         0           5            7            7          1         0
# 4         0           5            6            5          1         0
#
#    Exterior1st  Exterior2nd  MasVnrType  MasVnrArea  ExterQual  ExterCond  \
# 0            9           11           4       200.0          2          3
# 1            5            5           3         0.0          2          3
# 2            9           11           3         0.0          2          3
# 3            6            7           3         0.0          3          3
# 4            9           11           4        74.0          2          3
#
#    Foundation  BsmtQual  BsmtCond  BsmtExposure  BsmtFinType1  BsmtFinType2  \
# 0           2         0         3             1             2             6
# 1           1         2         3             0             2             6
# 2           2         2         3             0             6             6
# 3           1         4         3             4             5             6
# 4           2         2         3             2             6             6
#
#    Heating  HeatingQC  CentralAir  Electrical  2ndFlrSF  LowQualFinSF  \
# 0        0          0           1           3         0             0
# 1        0          2           1           3         0             0
# 2        0          0           1           3         0             0
# 3        0          0           1           3       704             0
# 4        0          0           1           3      1039             0
#
#    GrLivArea  BedroomAbvGr  KitchenAbvGr  KitchenQual  TotRmsAbvGrd  \
# 0       1922             3             1            2             8
# 1       1360             1             1            2             4
# 2       1788             3             1            0             7
# 3       1564             3             1            1             7
# 4       1933             4             1            2             9
#
#    Functional  Fireplaces  FireplaceQu  GarageType  GarageFinish  GarageCars  \
# 0           5           1            2           1             0           3
# 1           5           1            0           1             1           2
# 2           5           1            4           1             1           2
# 3           5           1            2           1             2           1
# 4           5           1            2           3             0           3
#
#    GarageArea  GarageQual  GarageCond  PavedDrive  WoodDeckSF  PoolArea  \
# 0         676           4           4           2         178         0
# 1         565           4           4           2          63         0
# 2         522           4           4           2         202         0
# 3         234           4           4           2           0         0
# 4         668           4           4           2         100         0
#
#    MiscVal  MoSold  SaleType  SaleCondition  BsmtBath  Bath  Total_porch
# 0        0       7         5              2       1.0   2.0           51
# 1        0       8         0              0       1.0   1.0            0
# 2        0       6         5              2       0.0   2.0          151
# 3        0       7         5              2       0.0   1.5            0
# 4        0       1         5              2       0.0   2.5           18

# %% [markdown]
# ### Scaling the Model

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
hs = sc.fit_transform(x)

# %% [markdown]
# ### Training Process

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
lr = LinearRegression()

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor

from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %% [markdown]
# ### Random State

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.30,random_state=i)
    lr.fit(x_train,y_train)
    pred_tr = lr.predict(x_train)
    pred_ts = lr.predict(x_test)
    print(f"At random state {i},the training accuracy is : {r2_score(y_train,pred_tr)}")
    print(f"At random state {i},the testing accuracy is : {r2_score(y_test,pred_ts)}")
    print("\n")
# Out:
# At random state 0,the training accuracy is : 0.8649247264936992
# At random state 0,the testing accuracy is : 0.8082352995722669
#
#
# At random state 1,the training accuracy is : 0.8574935395767996
# At random state 1,the testing accuracy is : 0.8419765951366185
#
#
# At random state 2,the training accuracy is : 0.8635643197432396
# At random state 2,the testing accuracy is : 0.7979511236812576
#
#
# At random state 3,the training accuracy is : 0.8596420709895334
# At random state 3,the testing accuracy is : 0.8406167807688258
#
#
# At random state 4,the training accuracy is : 0.8634219932206929
# At random state 4,the testing accuracy is : 0.8074848642195581
#
#
# At random state 5,the training accuracy is : 0.8632562719361406
# At random state 5,the testing accuracy is : 0.7915676997796643
#
#
# At random state 6,the training accuracy is : 0.8598523636026157
# At random state 6,the testing accuracy is : 0.8380132336204594
#
#
# At random state 7,the training accuracy is : 0.8714593212628705
# At random state 7,the testing accuracy is : 0.7756967991048733
#
#
# At random state 8,the training accuracy is : 0.8788599481548279
# At random state 8,the testing accuracy is : 0.7330282215953378
#
#
# At random state 9,the training accuracy is : 0.8751300691828046
# At random state 9,the testing accuracy is : 0.7810014435347494
#
#
# At random state 10,the training accuracy is : 0.8556079825714195
# At random state 10,the testing accuracy is : 0.8485006945149671
#
#
# At random state 11,the training accuracy is : 0.8869193156771109
# At random state 11,the testing accuracy is : 0.708989864550382
#
#
# At random state 12,the training accuracy is : 0.8605589017180757
# At random state 12,the testing accuracy is : 0.8265013013298749
#
#
# At random state 13,the training accuracy is : 0.8571861137353057
# At random state 13,the testing accuracy is : 0.8304718155898803
#
#
# At random state 14,the training accuracy is : 0.8557711155458223
# At random state 14,the testing accuracy is : 0.8368272370135148
#
#
# At random state 15,the training accuracy is : 0.8748192072724583
# At random state 15,the testing accuracy is : 0.7915250193087521
#
#
# At random state 16,the training accuracy is : 0.8594730140805791
# At random state 16,the testing accuracy is : 0.8269964954616298
#
#
# At random state 17,the training accuracy is : 0.8707812093489142
# At random state 17,the testing accuracy is : 0.8054795480448715
#
#
# At random state 18,the training accuracy is : 0.8633887580305506
# At random state 18,the testing accuracy is : 0.8251006896398514
#
#
# At random state 19,the training accuracy is : 0.8465006888811699
# At random state 19,the testing accuracy is : 0.8674153163996601
#
#
# At random state 20,the training accuracy is : 0.876341234565976
# At random state 20,the testing accuracy is : 0.7892401772450196
#
#
# At random state 21,the training accuracy is : 0.8784963542507739
# At random state 21,the testing accuracy is : 0.7987047016774176
#
#
# At random state 22,the training accuracy is : 0.8707221705940482
# At random state 22,the testing accuracy is : 0.7819925460074839
#
#
# At random state 23,the training accuracy is : 0.8688813846440644
# At random state 23,the testing accuracy is : 0.8159540095175581
#
#
# At random state 24,the training accuracy is : 0.8611641122149084
# At random state 24,the testing accuracy is : 0.838078517790154
#
#
# At random state 25,the training accuracy is : 0.8838371608335757
# At random state 25,the testing accuracy is : 0.6881167577760405
#
#
# At random state 26,the training accuracy is : 0.8832440438058032
# At random state 26,the testing accuracy is : 0.7196702264093731
#
#
# At random state 27,the training accuracy is : 0.8835693501096729
# At random state 27,the testing accuracy is : 0.7044355038493967
#
#
# At random state 28,the training accuracy is : 0.8686473554719515
# At random state 28,the testing accuracy is : 0.7686661899940053
#
#
# At random state 29,the training accuracy is : 0.8588657407945749
# At random state 29,the testing accuracy is : 0.840802097884475
#
#
# At random state 30,the training accuracy is : 0.866808140518853
# At random state 30,the testing accuracy is : 0.8002767647035658
#
#
# At random state 31,the training accuracy is : 0.8609010302766811
# At random state 31,the testing accuracy is : 0.8370292140279655
#
#
# At random state 32,the training accuracy is : 0.8703777440345972
# At random state 32,the testing accuracy is : 0.7755497416529264
#
#
# At random state 33,the training accuracy is : 0.855764321056145
# At random state 33,the testing accuracy is : 0.8460373437439352
#
#
# At random state 34,the training accuracy is : 0.8907004200826686
# At random state 34,the testing accuracy is : 0.70019219008514
#
#
# At random state 35,the training accuracy is : 0.8731401054113457
# At random state 35,the testing accuracy is : 0.7982716369510736
#
#
# At random state 36,the training accuracy is : 0.8672431462596509
# At random state 36,the testing accuracy is : 0.8126066290414133
#
#
# At random state 37,the training accuracy is : 0.8867638149331497
# At random state 37,the testing accuracy is : 0.6793581881693966
#
#
# At random state 38,the training accuracy is : 0.8874551165406671
# At random state 38,the testing accuracy is : 0.6923249581596291
#
#
# At random state 39,the training accuracy is : 0.8594456593276207
# At random state 39,the testing accuracy is : 0.8336560860028054
#
#
# At random state 40,the training accuracy is : 0.8865854828882279
# At random state 40,the testing accuracy is : 0.7184067509911747
#
#
# At random state 41,the training accuracy is : 0.8639507763946093
# At random state 41,the testing accuracy is : 0.7754597485145207
#
#
# At random state 42,the training accuracy is : 0.8872347213241638
# At random state 42,the testing accuracy is : 0.7106331712689087
#
#
# At random state 43,the training accuracy is : 0.8622025471440563
# At random state 43,the testing accuracy is : 0.8337392189259292
#
#
# At random state 44,the training accuracy is : 0.8608185986135461
# At random state 44,the testing accuracy is : 0.837991363305699
#
#
# At random state 45,the training accuracy is : 0.8724120489142553
# At random state 45,the testing accuracy is : 0.7641876246806338
#
#
# At random state 46,the training accuracy is : 0.8664093212544499
# At random state 46,the testing accuracy is : 0.8110071654021465
#
#
# At random state 47,the training accuracy is : 0.8680885571020887
# At random state 47,the testing accuracy is : 0.8220326288899374
#
#
# At random state 48,the training accuracy is : 0.8557389739038385
# At random state 48,the testing accuracy is : 0.8475865800649318
#
#
# At random state 49,the training accuracy is : 0.859032524507532
# At random state 49,the testing accuracy is : 0.8381876776367105
#
#
# At random state 50,the training accuracy is : 0.8648107784998347
# At random state 50,the testing accuracy is : 0.8245075394410939
#
#
# At random state 51,the training accuracy is : 0.8494719372263719
# At random state 51,the testing accuracy is : 0.8622144728788871
#
#
# At random state 52,the training accuracy is : 0.8727316952251656
# At random state 52,the testing accuracy is : 0.7636534815137609
#
#
# At random state 53,the training accuracy is : 0.8632074632843154
# At random state 53,the testing accuracy is : 0.8272403858765989
#
#
# At random state 54,the training accuracy is : 0.8526637270673948
# At random state 54,the testing accuracy is : 0.858593392169335
#
#
# At random state 55,the training accuracy is : 0.8564062586183476
# At random state 55,the testing accuracy is : 0.8481946809507356
#
#
# At random state 56,the training accuracy is : 0.8511755624257944
# At random state 56,the testing accuracy is : 0.8618556109380666
#
#
# At random state 57,the training accuracy is : 0.8603354724300843
# At random state 57,the testing accuracy is : 0.8316310489925322
#
#
# At random state 58,the training accuracy is : 0.8656736737127417
# At random state 58,the testing accuracy is : 0.8238740663877734
#
#
# At random state 59,the training accuracy is : 0.8668528652549856
# At random state 59,the testing accuracy is : 0.7851197127246773
#
#
# At random state 60,the training accuracy is : 0.8538953711027194
# At random state 60,the testing accuracy is : 0.8545491950889543
#
#
# At random state 61,the training accuracy is : 0.8593001227119488
# At random state 61,the testing accuracy is : 0.8372262488968525
#
#
# At random state 62,the training accuracy is : 0.8710249456472677
# At random state 62,the testing accuracy is : 0.8043203555698033
#
#
# At random state 63,the training accuracy is : 0.8850471867464635
# At random state 63,the testing accuracy is : 0.72861630383571
#
#
# At random state 64,the training accuracy is : 0.863869226315193
# At random state 64,the testing accuracy is : 0.8109658792061938
#
#
# At random state 65,the training accuracy is : 0.8681544293133956
# At random state 65,the testing accuracy is : 0.7649696691894987
#
#
# At random state 66,the training accuracy is : 0.8588035570271104
# At random state 66,the testing accuracy is : 0.829356432443165
#
#
# At random state 67,the training accuracy is : 0.8780480245921123
# At random state 67,the testing accuracy is : 0.7320791015384429
#
#
# At random state 68,the training accuracy is : 0.8725012588187865
# At random state 68,the testing accuracy is : 0.7869897649085364
#
#
# At random state 69,the training accuracy is : 0.8540043187194595
# At random state 69,the testing accuracy is : 0.8530786258053514
#
#
# At random state 70,the training accuracy is : 0.8648704790964913
# At random state 70,the testing accuracy is : 0.8307314239046689
#
#
# At random state 71,the training accuracy is : 0.8572581033760831
# At random state 71,the testing accuracy is : 0.8457417079132447
#
#
# At random state 72,the training accuracy is : 0.8809755201107234
# At random state 72,the testing accuracy is : 0.764956869882424
#
#
# At random state 73,the training accuracy is : 0.861607221803467
# At random state 73,the testing accuracy is : 0.8370442931871515
#
#
# At random state 74,the training accuracy is : 0.8734691706868112
# At random state 74,the testing accuracy is : 0.7819334615386037
#
#
# At random state 75,the training accuracy is : 0.8835671252887929
# At random state 75,the testing accuracy is : 0.6826223499326507
#
#
# At random state 76,the training accuracy is : 0.86071104437118
# At random state 76,the testing accuracy is : 0.8338251350816366
#
#
# At random state 77,the training accuracy is : 0.8810139236880019
# At random state 77,the testing accuracy is : 0.7661434893624913
#
#
# At random state 78,the training accuracy is : 0.8619689439676548
# At random state 78,the testing accuracy is : 0.8091645601745241
#
#
# At random state 79,the training accuracy is : 0.8800873163398412
# At random state 79,the testing accuracy is : 0.7355181095508904
#
#
# At random state 80,the training accuracy is : 0.8562937875323555
# At random state 80,the testing accuracy is : -4.68134060008963e+22
#
#
# At random state 81,the training accuracy is : 0.8559277685830662
# At random state 81,the testing accuracy is : 0.8483130383261901
#
#
# At random state 82,the training accuracy is : 0.8858911763073731
# At random state 82,the testing accuracy is : 0.6877901396064098
#
#
# At random state 83,the training accuracy is : 0.8655432122667375
# At random state 83,the testing accuracy is : 0.788362999413279
#
#
# At random state 84,the training accuracy is : 0.8743496005945062
# At random state 84,the testing accuracy is : 0.798105376654854
#
#
# At random state 85,the training accuracy is : 0.8772795661416117
# At random state 85,the testing accuracy is : 0.7241666995731607
#
#
# At random state 86,the training accuracy is : 0.8542856530341097
# At random state 86,the testing accuracy is : 0.8500291300084772
#
#
# At random state 87,the training accuracy is : 0.8721080577693406
# At random state 87,the testing accuracy is : 0.806325010246204
#
#
# At random state 88,the training accuracy is : 0.8705743123224112
# At random state 88,the testing accuracy is : 0.8041131807852789
#
#
# At random state 89,the training accuracy is : 0.8585710407531046
# At random state 89,the testing accuracy is : 0.8416482863458339
#
#
# At random state 90,the training accuracy is : 0.8593358839317466
# At random state 90,the testing accuracy is : 0.7927191457789966
#
#
# At random state 91,the training accuracy is : 0.8637397807966471
# At random state 91,the testing accuracy is : 0.8117349926714337
#
#
# At random state 92,the training accuracy is : 0.8722832220722101
# At random state 92,the testing accuracy is : 0.8100523547446077
#
#
# At random state 93,the training accuracy is : 0.8558536336339718
# At random state 93,the testing accuracy is : 0.8459866651671033
#
#
# At random state 94,the training accuracy is : 0.8598104043896939
# At random state 94,the testing accuracy is : 0.8372964479716779
#
#
# At random state 95,the training accuracy is : 0.8833779183761225
# At random state 95,the testing accuracy is : 0.7119986110654208
#
#
# At random state 96,the training accuracy is : 0.8490015713070316
# At random state 96,the testing accuracy is : 0.8623830104030465
#
#
# At random state 97,the training accuracy is : 0.8582853338216868
# At random state 97,the testing accuracy is : 0.842739703460549
#
#
# At random state 98,the training accuracy is : 0.8803705548672488
# At random state 98,the testing accuracy is : 0.7379855034489178
#
#
# At random state 99,the training accuracy is : 0.8529835594816707
# At random state 99,the testing accuracy is : 0.8456242860259082

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.30,random_state=69)

# %%
x_train.shape
# Out:
# (786, 61)

# %%
x_test.shape
# Out:
# (337, 61)

# %%
y_train.shape
# Out:
# (786,)

# %%
y_test.shape
# Out:
# (337,)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_ts = lr.predict(x_test)

# %%
print(r2_score(y_test,pred_ts))
# Out:
# 0.8530786258053514

# %% [markdown]
# ###### r2 score is 85.30.

# %% [markdown]
# ### Cross Validation Score

# %%
tr_accu = r2_score(y_train,pred_tr)
ts_accu = r2_score(y_test,pred_ts)

from sklearn.model_selection import cross_val_score
for j in range(2,20):
    cv_score = cross_val_score(lr,x,y,cv=j)
    cv_mean = cv_score.mean()
    print(f"At cross fold{j} the cv score {cv_mean} and accuracy score for training is {tr_accu} and accuracy for testing is {ts_accu}")
    print("\n")
# Out:
# At cross fold2 the cv score -1.3025231349048781e+23 and accuracy score for training is -0.740682120018108 and accuracy for testing is 0.8530786258053514
#
#
# At cross fold3 the cv score 0.8046657249342059 and accuracy score for training is -0.740682120018108 and accuracy for testing is 0.8530786258053514
#
#
# At cross fold4 the cv score 0.8112786346157745 and accuracy score for training is -0.740682120018108 and accuracy for testing is 0.8530786258053514
#
#
# At cross fold5 the cv score 0.8075255320217801 and accuracy score for training is -0.740682120018108 and accuracy for testing is 0.8530786258053514
#
#
# At cross fold6 the cv score 0.8124253169720479 and accuracy score for training is -0.740682120018108 and accuracy for testing is 0.8530786258053514
#
#
# At cross fold7 the cv score 0.8079715346857216 and accuracy score for training is -0.740682120018108 and accuracy for testing is 0.8530786258053514
#
#
# At cross fold8 the cv score 0.8131561298172731 and accuracy score for training is -0.740682120018108 and accuracy for testing is 0.8530786258053514
#
#
# At cross fold9 the cv score 0.8116650087830687 and accuracy score for training is -0.740682120018108 and accuracy for testing is 0.8530786258053514
#
#
# At cross fold10 the cv score 0.8086498099581938 and accuracy score for training is -0.740682120018108 and accuracy for testing is 0.8530786258053514
#
#
# At cross fold11 the cv score 0.8049799433629524 and accuracy score for training is -0.740682120018108 and accuracy for testing is 0.8530786258053514
#
#
# At cross fold12 the cv score 0.8116387849894425 and accuracy score for training is -0.740682120018108 and accuracy for testing is 0.8530786258053514
#
#
# At cross fold13 the cv score 0.8092073745130397 and accuracy score for training is -0.740682120018108 and accuracy for testing is 0.8530786258053514
#
#
# At cross fold14 the cv score 0.8041149833097652 and accuracy score for training is -0.740682120018108 and accuracy for testing is 0.8530786258053514
#
#
# At cross fold15 the cv score 0.8057622556623846 and accuracy score for training is -0.740682120018108 and accuracy for testing is 0.8530786258053514
#
#
# At cross fold16 the cv score 0.8064094885107373 and accuracy score for training is -0.740682120018108 and accuracy for testing is 0.8530786258053514
#
#
# At cross fold17 the cv score 0.8067296989383858 and accuracy score for training is -0.740682120018108 and accuracy for testing is 0.8530786258053514
#
#
# At cross fold18 the cv score 0.8072044767009424 and accuracy score for training is -0.740682120018108 and accuracy for testing is 0.8530786258053514
#
#
# At cross fold19 the cv score 0.8109038938847452 and accuracy score for training is -0.740682120018108 and accuracy for testing is 0.8530786258053514

# %% [markdown]
# ###### At cross fold 8 we got our best cv score : 81.31.

# %% [markdown]
# ### Model Testing

# %%
def train(model,x,y):
    model.fit(x,y)
    pred = model.predict(x)
    cv_score = cross_val_score(model,x,y,cv=8)
    cv_score = np.abs(np.mean(cv_score))
    print('Model Report')
    print('MSE',mean_squared_error(y,pred))
    print('CV',cv_score)

# %%
model = LinearRegression()
train(model,x,y)
coef = pd.Series(model.coef_,x.columns).sort_values()
coef.plot(kind = 'bar',title = 'Model Coefficient')
# Out:
# Model Report
# MSE 501113312.4375796
# CV 0.8131561298172731
# <AxesSubplot:title={'center':'Model Coefficient'}>

# %%
model = Ridge(normalize=True)
train(model,x,y)
coef = pd.Series(model.coef_,x.columns).sort_values()
coef.plot(kind = 'bar',title = 'Model Coefficients')
# Out:
# Model Report
# MSE 652110389.6752236
# CV 0.8016383664232377
# <AxesSubplot:title={'center':'Model Coefficients'}>

# %%
model = Lasso()
train(model,x,y)
coef = pd.Series(model.coef_,x.columns).sort_values()
coef.plot(kind = 'bar',title = 'Model Coefficients')
# Out:
# Model Report
# MSE 501113321.4305417
# CV 0.8131849398129503
# <AxesSubplot:title={'center':'Model Coefficients'}>

# %%
model = DecisionTreeRegressor()
train(model,x,y)
coef = pd.Series(model.feature_importances_,x.columns).sort_values(ascending=False)
coef.plot(kind = 'bar',title = 'Feature Importance')
# Out:
# Model Report
# MSE 0.0
# CV 0.6929222652144635
# <AxesSubplot:title={'center':'Feature Importance'}>

# %%
model = RandomForestRegressor()
train(model,x,y)
coef = pd.Series(model.feature_importances_,x.columns).sort_values()
coef.plot(kind = 'bar',title = 'Feature Importance')
# Out:
# Model Report
# MSE 72566852.7817496
# CV 0.8543433423407458
# <AxesSubplot:title={'center':'Feature Importance'}>

# %%
model = ExtraTreesRegressor()
train(model,x,y)
coef = pd.Series(model.feature_importances_,x.columns).sort_values()
coef.plot(kind = 'bar',title = 'Feature Importance')
# Out:
# Model Report
# MSE 0.0
# CV 0.8583491262158044
# <AxesSubplot:title={'center':'Feature Importance'}>

# %%
model = AdaBoostRegressor()
train(model,x,y)
coef = pd.Series(model.feature_importances_,x.columns).sort_values()
coef.plot(kind = 'bar',title = 'Feature Importance')
# Out:
# Model Report
# MSE 504818148.3783949
# CV 0.8064202283613306
# <AxesSubplot:title={'center':'Feature Importance'}>

# %% [markdown]
# ###### We can see that CV score for Extra Tree Regressor model is higher than the other model.

# %% [markdown]
# ### Hyper Parameter Tuning

# %%
ExtraTreesRegressor()
# Out:
# ExtraTreesRegressor()

# %%
from sklearn.model_selection import GridSearchCV
parameters = {'criterion' : ["squared_error", "absolute_error"],
             'max_features' : ["auto", "sqrt", "log2"],}

# %%
GCV = GridSearchCV(ExtraTreesRegressor(),parameters,cv=8,scoring='neg_mean_absolute_error')
GCV.fit(x_train,y_train)
GCV.best_params_
# Out:
# {'criterion': 'squared_error', 'max_features': 'auto'}

# %%
GCV.best_estimator_
# Out:
# ExtraTreesRegressor()

# %%
et = ExtraTreesRegressor(criterion='squared_error',max_features='auto')
cv_score = cross_val_score(model,x,y,cv=8)
cv_score = np.abs(np.mean(cv_score))
print('CV',cv_score)
# Out:
# CV 0.8014192200911208

# %% [markdown]
# #### Random Forest Regressor

# %%
RandomForestRegressor()
# Out:
# RandomForestRegressor()

# %%
parameters = {'criterion' : ["squared_error", "absolute_error", "poisson"],
             'max_features' : ["auto", "sqrt", "log2"]}

# %%
GCV = GridSearchCV(RandomForestRegressor(),parameters,cv=8,scoring='neg_mean_absolute_error')
GCV.fit(x_train,y_train)
GCV.best_params_
# Out:
# {'criterion': 'squared_error', 'max_features': 'sqrt'}

# %%
rf = RandomForestRegressor(criterion='squared_error',max_features='sqrt')
cv_score = cross_val_score(model,x,y,cv=8)
cv_score = np.abs(np.mean(cv_score))
print('CV',cv_score)
# Out:
# CV 0.8041536629299985

# %% [markdown]
# #### Lasso

# %%
Lasso()
# Out:
# Lasso()

# %%
parameters = {'max_iter' : [1,10,100,1000],'selection' : ['cyclic', 'random'] }

# %%
GCV = GridSearchCV(Lasso(),parameters,cv=8,scoring='neg_mean_absolute_error')
GCV.fit(x_train,y_train)
GCV.best_params_
# Out:
# {'max_iter': 1000, 'selection': 'random'}

# %%
rf = Lasso(max_iter=1000,selection='random')
cv_score = cross_val_score(model,x,y,cv=8)
cv_score = np.abs(np.mean(cv_score))
print('CV',cv_score)
# Out:
# CV 0.8052183941105735

# %% [markdown]
# ###### We seen that after doing Hyper Parameter Tuning CV score gets reduced,so we choose Extra Tree Regressor Model as our final model without Hyoer Parameter Tuning.
